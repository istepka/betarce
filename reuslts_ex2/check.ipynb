# %%
import pandas as pd 
import os 
import seaborn as sns
import matplotlib.pyplot as plt

# Set the style of the plots
markers = ['o', 's', 'D', 'v', 'p', 'P', 'X', 'h', 'H', 'd']
colors_discrete = sns.color_palette('tab10')
colors_continuous = sns.color_palette('viridis')


# Do not hide any columns
pd.set_option('display.max_columns', None)


# Read all the results from results/ directory
results = []
for file in os.listdir('results'):
    if file.endswith('.feather'):
        results.append(pd.read_feather(f'results/{file}'))

# Concatenate all the results
df: pd.DataFrame = pd.concat(results, ignore_index=True)

df.head(5)
# Out:
#           experiment_type dataset_name  k_mlps_in_B  fold_i  \
# 0  Bootstrap-Architecture         fico           32       0
# 1  Bootstrap-Architecture         fico           32       0
# 2  Bootstrap-Architecture         fico           32       0
# 3  Bootstrap-Architecture         fico           32       0
# 4  Bootstrap-Architecture         fico           32       0
#
#   experiment_generalization_type  beta_confidence  delta_robustness  \
# 0         Bootstrap-Architecture              0.8               0.5
# 1         Bootstrap-Architecture              0.8               0.5
# 2         Bootstrap-Architecture              0.8               0.5
# 3         Bootstrap-Architecture              0.8               0.5
# 4         Bootstrap-Architecture              0.8               0.5
#
#   model2_name                                      x_test_sample  \
# 0    Model2_0  [0.423076923076923, 0.19897084048027444, 0.169...
# 1    Model2_0  [0.423076923076923, 0.19897084048027444, 0.169...
# 2    Model2_1  [0.423076923076923, 0.19897084048027444, 0.169...
# 3    Model2_1  [0.423076923076923, 0.19897084048027444, 0.169...
# 4    Model2_2  [0.423076923076923, 0.19897084048027444, 0.169...
#
#    y_test_sample  model1_pred_proba  model1_pred_crisp  model2_pred_proba  \
# 0              0           0.134287                  0           0.147861
# 1              0           0.134287                  0           0.147861
# 2              0           0.134287                  0           0.125619
# 3              0           0.134287                  0           0.125619
# 4              0           0.134287                  0           0.104445
#
#    model2_pred_crisp                                base_counterfactual  \
# 0                  0  [0.7545202377021992, 0.030409299805246953, 0.2...
# 1                  0                                               None
# 2                  0  [0.7545202377021992, 0.030409299805246953, 0.2...
# 3                  0                                               None
# 4                  0  [0.7545202377021992, 0.030409299805246953, 0.2...
#
#   base_counterfactual_model1_pred_proba base_counterfactual_model1_pred_crisp  \
# 0                               0.51012                                   1.0
# 1                                   NaN                                   NaN
# 2                               0.51012                                   1.0
# 3                                   NaN                                   NaN
# 4                               0.51012                                   1.0
#
#   base_counterfactual_model2_pred_proba base_counterfactual_model2_pred_crisp  \
# 0                              0.601298                                   1.0
# 1                                   NaN                                   NaN
# 2                              0.444571                                   0.0
# 3                                   NaN                                   NaN
# 4                              0.562796                                   1.0
#
#   base_counterfactual_validity base_counterfactual_proximityL1  \
# 0                          1.0                        2.940069
# 1                          NaN                             NaN
# 2                          1.0                        2.940069
# 3                          NaN                             NaN
# 4                          1.0                        2.940069
#
#   base_counterfactual_proximityL2 base_counterfactual_plausibility  \
# 0                         0.73164                          0.66634
# 1                             NaN                              NaN
# 2                         0.73164                          0.66634
# 3                             NaN                              NaN
# 4                         0.73164                          0.66634
#
#   base_counterfactual_discriminative_power  \
# 0                                 0.666667
# 1                                      NaN
# 2                                 0.666667
# 3                                      NaN
# 4                                 0.666667
#
#   base_counterfactual_validity_model2 base_counterfactual_time  \
# 0                                 1.0                 0.021767
# 1                                 NaN                      NaN
# 2                                 0.0                 0.021767
# 3                                 NaN                      NaN
# 4                                 1.0                 0.021767
#
#                                robust_counterfactual  \
# 0                                               None
# 1  [0.7508948551947412, 0.03727385012071058, 0.23...
# 2                                               None
# 3  [0.7595146793183168, 0.03351878766569367, 0.23...
# 4                                               None
#
#    robust_counterfactual_model1_pred_proba  \
# 0                                      NaN
# 1                                 0.530759
# 2                                      NaN
# 3                                 0.529004
# 4                                      NaN
#
#    robust_counterfactual_model1_pred_crisp  \
# 0                                      NaN
# 1                                      1.0
# 2                                      NaN
# 3                                      1.0
# 4                                      NaN
#
#    robust_counterfactual_model2_pred_proba  \
# 0                                      NaN
# 1                                 0.613003
# 2                                      NaN
# 3                                 0.454427
# 4                                      NaN
#
#    robust_counterfactual_model2_pred_crisp  robust_counterfactual_validity  \
# 0                                      NaN                             NaN
# 1                                      1.0                             1.0
# 2                                      NaN                             NaN
# 3                                      0.0                             1.0
# 4                                      NaN                             NaN
#
#    robust_counterfactual_proximityL1  robust_counterfactual_proximityL2  \
# 0                                NaN                                NaN
# 1                           2.952354                           0.735085
# 2                                NaN                                NaN
# 3                           2.967001                           0.739852
# 4                                NaN                                NaN
#
#    robust_counterfactual_plausibility  \
# 0                                 NaN
# 1                            0.663830
# 2                                 NaN
# 3                            0.669554
# 4                                 NaN
#
#    robust_counterfactual_discriminative_power  \
# 0                                         NaN
# 1                                    0.666667
# 2                                         NaN
# 3                                    0.666667
# 4                                         NaN
#
#    robust_counterfactual_validity_model2  \
# 0                                    NaN
# 1                                    1.0
# 2                                    NaN
# 3                                    0.0
# 4                                    NaN
#
#    robust_counterfactual_L1_distance_from_base_cf  \
# 0                                             NaN
# 1                                        0.097824
# 2                                             NaN
# 3                                        0.076563
# 4                                             NaN
#
#    robust_counterfactual_L2_distance_from_base_cf  robust_counterfactual_time  \
# 0                                             NaN                         NaN
# 1                                        0.000624                   23.589093
# 2                                             NaN                         NaN
# 3                                        0.000429                    1.801428
# 4                                             NaN                         NaN
#
#    start_sample_passes_test  counterfactual_does_not_pass_test  \
# 0                       NaN                                NaN
# 1                       0.0                                0.0
# 2                       NaN                                NaN
# 3                       0.0                                0.0
# 4                       NaN                                NaN
#
#    counterfactual_does_not_have_target_class  counterfactual_is_nan  \
# 0                                        NaN                    NaN
# 1                                        0.0                    0.0
# 2                                        NaN                    NaN
# 3                                        0.0                    0.0
# 4                                        NaN                    NaN
#
#    highest_delta
# 0            NaN
# 1       0.512019
# 2            NaN
# 3       0.512019
# 4            NaN

# %%
df['start_sample_passes_test'].value_counts()
# Out:
# 0.0    131
# Name: start_sample_passes_test, dtype: int64

# %%
base_validity_model2 = df[df['base_counterfactual'] != None]['base_counterfactual_validity_model2'].dropna()
print('Average base_counterfactual_validity_model2:', base_validity_model2.mean())

robust_validity_model2 = df[df['robust_counterfactual'] != None]['robust_counterfactual_validity_model2'].dropna()
print('Average robust_counterfactual_validity_model2:', robust_validity_model2.mean())
# Out:
# Average base_counterfactual_validity_model2: 0.4666666666666667
# Average robust_counterfactual_validity_model2: 0.6793893129770993

# %%
robust = []
base = []

unique_deltas = df['delta_robustness'].unique()
# unique_confidences = df['beta_confidence'].unique()
confidence = 0.8


#Extract validity2 for each delta and confidence
for delta in unique_deltas:
    robust += [df[(df['delta_robustness'] == delta) & (df['beta_confidence'] == confidence)]['robust_counterfactual_validity_model2'].dropna().mean()]
    base += [df[(df['delta_robustness'] == delta) & (df['beta_confidence'] == confidence)]['base_counterfactual_validity_model2'].dropna().mean()]
        
#Plot the results
fig, ax = plt.subplots(1, 2, figsize=(15, 5))


plt.show()
