# %%
import pandas as pd
import numpy as np
import os
import seaborn as sns
import matplotlib.pyplot as plt
from tqdm import tqdm

while "src" not in os.listdir():
    os.chdir("..")

# Set the style of the plots
markers = ["o", "s", "D", "v", "p", "P", "X", "h", "H", "d"]
colors_discrete = sns.color_palette("tab10")
colors_continuous = sns.color_palette("viridis")
linestyles = ["-", "--", "-.", ":"]

# Do not hide any columns
pd.set_option("display.max_columns", None)
sns.set_theme(style="whitegrid", font_scale=1)

os.getcwd()
# Out:
# '/home/ignacy/research/betaRCE'

# %%
results_path = "results/corr"
images_dir = f"{results_path}/images"

os.makedirs(images_dir, exist_ok=True)

# %%
def process_results(results_path: str, ext: str = "feather"):
    results_list = []

    # Read all the results from results/ directory
    for dirname in tqdm(os.listdir(results_path), desc="Reading results"):
        if "images" not in dirname:
            if not os.path.isdir(
                f"{results_path}/{dirname}"
            ) or "results" not in os.listdir(f"{results_path}/{dirname}"):
                continue
            for file in os.listdir(f"{results_path}/{dirname}/results"):
                if file.endswith(f".{ext}"):
                    if ext == "csv":
                        df = pd.read_csv(f"{results_path}/{dirname}/results/{file}")
                    elif ext == "feather":
                        df = pd.read_feather(f"{results_path}/{dirname}/results/{file}")
                    else:
                        raise ValueError("Unknown extension")

                    # Custom parsing kinda weird
                    if "dt" in dirname:
                        df["base_model"] = "DecisionTree"
                    else:
                        df["base_model"] = "NeuralNetwork"

                    if "dice" in dirname:
                        df["base_cf_method"] = "Dice"
                    elif "rbr" in dirname:
                        df["base_cf_method"] = "RBR"
                    elif "roar" in dirname:
                        df["base_cf_method"] = "ROAR"
                    elif "face" in dirname:
                        df["base_cf_method"] = "FACE"
                    else:
                        df["base_cf_method"] = "GrowingSpheres"

                    print(dirname)

                    if "robx" in dirname:
                        df["robust_method"] = "robx"
                    else:
                        df["robust_method"] = "betaRCE"

                    # Temporary fix for the experiment type
                    # ----------------------------
                    # exp_types = list(filter(lambda x: 'seed' not in x.lower(), df['experiment_type'].unique()))
                    # df = df[df['experiment_type'].isin(exp_types)]
                    # ----------------------------

                    results_list.append(df)

    # Concatenate all the results
    raw_df: pd.DataFrame = pd.concat(results_list, ignore_index=True)
    return raw_df

# %%
raw_df = process_results(results_path)
# Out:
# Reading results:   0%|          | 0/5 [00:00<?, ?it/s]
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# Reading results:  20%|██        | 1/5 [00:01<00:06,  1.73s/it]
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# Reading results:  40%|████      | 2/5 [00:05<00:08,  2.76s/it]
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# robx_nn_gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# Reading results:  60%|██████    | 3/5 [00:07<00:04,  2.40s/it]
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes2
# gs_diabetes
# gs_diabetes
# gs_diabetes
# gs_diabetes
# gs_diabetes
# gs_diabetes
# gs_diabetes
# gs_diabetes
# gs_diabetes
# gs_diabetes
# gs_diabetes
# gs_diabetes
# gs_diabetes
# gs_diabetes
# gs_diabetes
# gs_diabetes
# gs_diabetes
# gs_diabetes
# gs_diabetes
# gs_diabetes
# gs_diabetes
# gs_diabetes
# gs_diabetes
# gs_diabetes
# gs_diabetes
# gs_diabetes
# gs_diabetes
# gs_diabetes
# gs_diabetes
# gs_diabetes
# gs_diabetes
# gs_diabetes
# gs_diabetes
# gs_diabetes
# gs_diabetes
# gs_diabetes
# gs_diabetes
# gs_diabetes
# gs_diabetes
# gs_diabetes
# gs_diabetes
# gs_diabetes
# gs_diabetes
# gs_diabetes
# gs_diabetes
# gs_diabetes
# gs_diabetes
# gs_diabetes
# gs_diabetes
# gs_diabetes
# gs_diabetes
# gs_diabetes
# gs_diabetes
# gs_diabetes
# gs_diabetes
# gs_diabetes
# gs_diabetes
# gs_diabetes
# gs_diabetes
# gs_diabetes
# gs_diabetes
# gs_diabetes
# gs_diabetes
# gs_diabetes
# gs_diabetes
# gs_diabetes
# gs_diabetes
# gs_diabetes
# gs_diabetes
# gs_diabetes
# gs_diabetes
# gs_diabetes
# gs_diabetes
# gs_diabetes
# gs_diabetes
# gs_diabetes
# gs_diabetes
# gs_diabetes
# gs_diabetes
# gs_diabetes
# gs_diabetes
# gs_diabetes
# gs_diabetes
# gs_diabetes
# gs_diabetes
# gs_diabetes
# gs_diabetes
# gs_diabetes
# gs_diabetes
# gs_diabetes
# gs_diabetes
# gs_diabetes
# gs_diabetes
# gs_diabetes
# gs_diabetes
# gs_diabetes
# gs_diabetes
# gs_diabetes
# gs_diabetes
# gs_diabetes
# gs_diabetes
# gs_diabetes
# gs_diabetes
# gs_diabetes
# gs_diabetes
# gs_diabetes
# gs_diabetes
# gs_diabetes
# gs_diabetes
# gs_diabetes
# gs_diabetes
# gs_diabetes
# gs_diabetes
# gs_diabetes
# gs_diabetes
# gs_diabetes
# gs_diabetes
# gs_diabetes
# gs_diabetes
# gs_diabetes
# Reading results: 100%|██████████| 5/5 [00:08<00:00,  1.60s/it]
# gs_diabetes
# gs_diabetes
# gs_diabetes
# gs_diabetes
# gs_diabetes
# gs_diabetes
# gs_diabetes
# gs_diabetes
# gs_diabetes
# gs_diabetes
# gs_diabetes
# gs_diabetes
# gs_diabetes
# gs_diabetes

# %%
# raw_df = raw_df.dropna()
raw_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105102 entries, 0 to 105101
# Data columns (total 51 columns):
#  #   Column                                          Non-Null Count   Dtype
# ---  ------                                          --------------   -----
#  0   base_cf_method                                  105102 non-null  object
#  1   model_type_to_use                               105102 non-null  object
#  2   experiment_type                                 105102 non-null  object
#  3   dataset_name                                    105102 non-null  object
#  4   k_mlps_in_B                                     105102 non-null  int64
#  5   fold_i                                          105102 non-null  int64
#  6   experiment_generalization_type                  105102 non-null  object
#  7   beta_confidence                                 105102 non-null  float64
#  8   delta_robustness                                105102 non-null  float64
#  9   model2_name                                     105102 non-null  object
#  10  x_test_sample                                   105102 non-null  object
#  11  y_test_sample                                   105102 non-null  int64
#  12  model1_pred_proba                               105102 non-null  float32
#  13  model1_pred_crisp                               105102 non-null  int64
#  14  model2_pred_proba                               105102 non-null  float32
#  15  model2_pred_crisp                               105102 non-null  int64
#  16  base_counterfactual                             105102 non-null  object
#  17  base_counterfactual_model1_pred_proba           100701 non-null  float32
#  18  base_counterfactual_model1_pred_crisp           100701 non-null  float64
#  19  base_counterfactual_model2_pred_proba           100701 non-null  float32
#  20  base_counterfactual_model2_pred_crisp           100701 non-null  float64
#  21  base_counterfactual_validity                    100701 non-null  float64
#  22  base_counterfactual_proximityL1                 100701 non-null  float64
#  23  base_counterfactual_proximityL2                 100701 non-null  float64
#  24  base_counterfactual_plausibility                100701 non-null  float64
#  25  base_counterfactual_discriminative_power        100701 non-null  float64
#  26  base_counterfactual_validity_model2             100701 non-null  float64
#  27  base_counterfactual_time                        105102 non-null  float64
#  28  robust_counterfactual                           94001 non-null   object
#  29  robust_counterfactual_model1_pred_proba         94001 non-null   float64
#  30  robust_counterfactual_model1_pred_crisp         94001 non-null   float64
#  31  robust_counterfactual_model2_pred_proba         94001 non-null   float64
#  32  robust_counterfactual_model2_pred_crisp         94001 non-null   float64
#  33  robust_counterfactual_validity                  94001 non-null   float64
#  34  robust_counterfactual_proximityL1               94001 non-null   float64
#  35  robust_counterfactual_proximityL2               94001 non-null   float64
#  36  robust_counterfactual_plausibility              94001 non-null   float64
#  37  robust_counterfactual_discriminative_power      94001 non-null   float64
#  38  robust_counterfactual_validity_model2           94001 non-null   float64
#  39  robust_counterfactual_L1_distance_from_base_cf  94001 non-null   float64
#  40  robust_counterfactual_L2_distance_from_base_cf  94001 non-null   float64
#  41  robust_counterfactual_time                      100701 non-null  float64
#  42  base_model                                      105102 non-null  object
#  43  robust_method                                   105102 non-null  object
#  44  start_sample_passes_test                        36000 non-null   float64
#  45  counterfactual_does_not_pass_test               36000 non-null   float64
#  46  counterfactual_does_not_have_target_class       36000 non-null   float64
#  47  counterfactual_is_nan                           36000 non-null   float64
#  48  highest_delta                                   36000 non-null   float64
#  49  lower_bound_beta                                36000 non-null   float64
#  50  upper_bound_beta                                36000 non-null   float64
# dtypes: float32(4), float64(31), int64(5), object(11)
# memory usage: 39.3+ MB

# %%
raw_df["robust_method"].value_counts()
# Out:
# robx       64701
# betaRCE    40401
# Name: robust_method, dtype: int64

# %%
base = [
    "base_counterfactual_proximityL1",
    "base_counterfactual_proximityL2",
    "base_counterfactual_plausibility",
    # 'base_counterfactual_discriminative_power'
]

robust = [
    "robust_counterfactual_proximityL1",
    "robust_counterfactual_proximityL2",
    "robust_counterfactual_plausibility",
    # 'robust_counterfactual_discriminative_power'
]

metrics = [
    "proximityL1",
    "proximityL2",
    "plausibility",
    # 'discriminative_power'
]

reference = "robust_counterfactual_L1_distance_from_base_cf"

# %%
new_df = raw_df.copy()[base + robust + [reference, "robust_method"]]
# new_df['base_counterfactual_discriminative_power'] = 1 - new_df['base_counterfactual_discriminative_power']
# new_df['robust_counterfactual_discriminative_power'] = 1 - new_df['robust_counterfactual_discriminative_power']

# Calculate the percentage of change
for met in metrics:
    new_df["perc_change_" + met] = (
        new_df["base_counterfactual_" + met] - new_df["robust_counterfactual_" + met]
    ) / new_df["base_counterfactual_" + met]

new_df["reference"] = raw_df[reference]
new_df = new_df.dropna()

new_df
# Out:
#         base_counterfactual_proximityL1  base_counterfactual_proximityL2  \
# 0                              0.409785                         0.158838
# 1                              0.409785                         0.158838
# 2                              0.409785                         0.158838
# 3                              0.409785                         0.158838
# 4                              0.409785                         0.158838
# ...                                 ...                              ...
# 105097                         0.772353                         0.335460
# 105098                         0.772353                         0.335460
# 105099                         0.772353                         0.335460
# 105100                         0.772353                         0.335460
# 105101                         0.772353                         0.335460
#
#         base_counterfactual_plausibility  robust_counterfactual_proximityL1  \
# 0                               0.269307                           0.768407
# 1                               0.269307                           0.768407
# 2                               0.269307                           0.768407
# 3                               0.269307                           0.740070
# 4                               0.269307                           0.768407
# ...                                  ...                                ...
# 105097                          0.476549                           1.325894
# 105098                          0.476549                           1.280584
# 105099                          0.476549                           1.439481
# 105100                          0.476549                           1.358954
# 105101                          0.476549                           1.438278
#
#         robust_counterfactual_proximityL2  robust_counterfactual_plausibility  \
# 0                                0.381826                            0.258264
# 1                                0.381826                            0.258264
# 2                                0.381826                            0.258264
# 3                                0.365968                            0.257338
# 4                                0.381826                            0.258264
# ...                                   ...                                 ...
# 105097                           0.628725                            0.527263
# 105098                           0.606291                            0.498386
# 105099                           0.685601                            0.623130
# 105100                           0.593061                            0.457518
# 105101                           0.653857                            0.521002
#
#         robust_counterfactual_L1_distance_from_base_cf robust_method  \
# 0                                             0.594942          robx
# 1                                             0.594942          robx
# 2                                             0.594942          robx
# 3                                             0.558759          robx
# 4                                             0.594942          robx
# ...                                                ...           ...
# 105097                                        0.901690       betaRCE
# 105098                                        0.796966       betaRCE
# 105099                                        0.914266       betaRCE
# 105100                                        0.839915       betaRCE
# 105101                                        1.009457       betaRCE
#
#         perc_change_proximityL1  perc_change_proximityL2  \
# 0                     -0.875145                -1.403874
# 1                     -0.875145                -1.403874
# 2                     -0.875145                -1.403874
# 3                     -0.805994                -1.304039
# 4                     -0.875145                -1.403874
# ...                         ...                      ...
# 105097                -0.716693                -0.874216
# 105098                -0.658030                -0.807339
# 105099                -0.863760                -1.043761
# 105100                -0.759498                -0.767900
# 105101                -0.862202                -0.949134
#
#         perc_change_plausibility  reference
# 0                       0.041005   0.594942
# 1                       0.041005   0.594942
# 2                       0.041005   0.594942
# 3                       0.044444   0.558759
# 4                       0.041005   0.594942
# ...                          ...        ...
# 105097                 -0.106420   0.901690
# 105098                 -0.045824   0.796966
# 105099                 -0.307587   0.914266
# 105100                  0.039935   0.839915
# 105101                 -0.093281   1.009457
#
# [94001 rows x 12 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

trans = {
    "proximityL1": "Proximity (L1)",
    "proximityL2": "Proximity (L2)",
    "plausibility": "Plausibility",
}

# Create individual figures for each metric
for metric in metrics:
    # Create a figure with a custom grid layout
    fig = plt.figure(figsize=(8, 6))

    sns.jointplot(
        data=new_df.sample(10000),
        x="reference",
        y=f"perc_change_{metric}",
        kind="scatter",
        alpha=0.5,
    )

    metric = trans[metric]

    # draw black line at y=0
    plt.axhline(0, color="black", linestyle="--")
    plt.xlabel("Distance to Base")
    plt.ylabel(f"Percentage Change in {metric}")

    plt.savefig(
        f"{images_dir}/percent_change_vs_reference_{metric}.png",
        dpi=300,
        bbox_inches="tight",
    )
    plt.show()
    plt.close()  # Close the figure to free up memory

# %%
from scipy.stats import pearsonr, spearmanr
import numpy as np

# Initialize the LaTeX table header
latex_table = """
\\begin{table}[ht]
\\centering
\\begin{tabular}{|l|l|l|l|}
\\hline
Metric & Method & rho & p-value \\\\
\\hline
"""

# Loop through robust methods
for robust_meth in new_df["robust_method"].unique():
    __new_df = new_df  # [new_df["robust_method"] == robust_meth]
    corrs = {}

    # Calculate correlations for each metric
    for met in metrics:
        rho, p = pearsonr(__new_df[f"perc_change_{met}"], __new_df["reference"])
        rho_s, p_s = spearmanr(__new_df[f"perc_change_{met}"], __new_df["reference"])

        corrs[met + "_pears"] = (rho, p)
        corrs[met + "_spear"] = (rho_s, p_s)

    # Calculate average correlations
    avg_pearson = np.mean([rho for k, (rho, _) in corrs.items() if "pears" in k])
    avg_spearman = np.mean([rho for k, (rho, _) in corrs.items() if "spear" in k])
    corrs["avg_pearson"] = avg_pearson
    corrs["avg_spearman"] = avg_spearman

    # Add robust method header to LaTeX table
    latex_table += f"\\multicolumn{{4}}{{|c|}}{{\\textbf{{Robust method: {robust_meth}}}}} \\\\ \\hline\n"

    # Loop through the correlations and add each to the LaTeX table
    for met, d in corrs.items():
        if not met.startswith("avg"):
            rho, p = d
            latex_table += f"{met.replace('_pears', '').replace('_spear', '')} & {'Pearson' if 'pears' in met else 'Spearman'} & {rho:.2f} & {p:.2f} \\\\ \\hline\n"
        else:
            latex_table += (
                f"Average {met.replace('avg_', '')} &  & {d:.2f} & \\\\ \\hline\n"
            )

# Close the LaTeX table
latex_table += """
\\end{tabular}
\\caption{Correlation Results for Different Robust Methods}
\\end{table}
"""

# Output the LaTeX code
print(latex_table)
# Out:
# \begin{table}[ht]
# \centering
# \begin{tabular}{|l|l|l|l|}
# \hline
# Metric & Method & rho & p-value \\
# \hline
# \multicolumn{4}{|c|}{\textbf{Robust method: robx}} \\ \hline
# proximityL1 & Pearson & -0.31 & 0.00 \\ \hline
# proximityL1 & Spearman & -0.70 & 0.00 \\ \hline
# proximityL2 & Pearson & -0.31 & 0.00 \\ \hline
# proximityL2 & Spearman & -0.73 & 0.00 \\ \hline
# plausibility & Pearson & -0.31 & 0.00 \\ \hline
# plausibility & Spearman & -0.02 & 0.00 \\ \hline
# Average pearson &  & -0.31 & \\ \hline
# Average spearman &  & -0.48 & \\ \hline
# \multicolumn{4}{|c|}{\textbf{Robust method: betaRCE}} \\ \hline
# proximityL1 & Pearson & -0.31 & 0.00 \\ \hline
# proximityL1 & Spearman & -0.70 & 0.00 \\ \hline
# proximityL2 & Pearson & -0.31 & 0.00 \\ \hline
# proximityL2 & Spearman & -0.73 & 0.00 \\ \hline
# plausibility & Pearson & -0.31 & 0.00 \\ \hline
# plausibility & Spearman & -0.02 & 0.00 \\ \hline
# Average pearson &  & -0.31 & \\ \hline
# Average spearman &  & -0.48 & \\ \hline
#
# \end{tabular}
# \caption{Correlation Results for Different Robust Methods}
# \end{table}

# %%
# Calculate the correlation between the percentage change and the reference distance
print(corrs)
corrs = pd.DataFrame(corrs, index=["rho", "p-value"]).replace(0, 0.0001)
# rename reference to distance
corrs = corrs.rename(
    index={"reference": "dist. to base"}, columns={"reference": "dist. to base"}
)

# Plot seaborn heatmap with annotations
plt.figure(figsize=(8, 6))
sns.heatmap(corrs, annot=True, cmap="coolwarm", center=0)
plt.title("Correlation between percentage change and reference distance")
plt.savefig(f"{images_dir}/correlation_heatmap.png")
plt.show()
# Out:
# {'proximityL1_pears': (-0.48091378690767045, 0.0), 'proximityL1_spear': (-0.8522593078364115, 0.0), 'proximityL2_pears': (-0.5162890764360528, 0.0), 'proximityL2_spear': (-0.8633157290464186, 0.0), 'plausibility_pears': (-0.36195307532209264, 0.0), 'plausibility_spear': (-0.3331617000651668, 0.0), 'avg_pearson': -0.45305197955527204, 'avg_spearman': -0.6829122456493323}

# %%
# Calculate correlation between the percentage change in plausibility and proximity L1 and the reference distance as one
# This is done to see if the reference distance is a good indicator of the percentage change in the metrics
# Aggregate this as one metric
